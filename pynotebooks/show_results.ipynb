# %%
from simpy import *
from simpy.struct import Results
from simpy import data
import simpy.plot as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
out_dir = '/home/vrastil/Documents/GIT/Adhesion-Approximation/output/'
res = Results(out_dir)

# %%
res.info(app='FP')

# %%
res.show_folder(res.get_subfiles(app='FP', L=2000)[0])

# %%
res.show_results(app='FP', Nm=512, plots=["pwr_spec"])

# %%
sim_info_nu0 = res.get_subfiles(app='AA', Nm=512, nu=1.0)[0]
res.plot_supp_compare(out_dir='/home/vrastil/Documents/GIT/Adhesion-Approximation/output/supp_comparison/AA_',
                      Nm=512, app='AA', scale=['small', 'medium', 'large'], show_k_lms=True, res=sim_info_nu0)

# %%
res.plot_supp_compare(out_dir='/home/vrastil/Documents/GIT/Adhesion-Approximation/output/supp_comparison/res_0.25_',
                      Nm=256, nu=3.0, scale=['small', 'medium', 'large'], show_k_lms=True)
